# %%
import pandas as pd

# %%
df = pd.read_csv("../dataset/crop_yield.csv")

# %%
df.head()
# Out:
#    Year           State          Crop      Season      Area  Production  \
# 0  2009  Madhya Pradesh  Sweet potato  Whole Year   3497.00    20803.00
# 1  2025  Madhya Pradesh     Sunflower      Kharif   1088.98     1198.25
# 2  2001        Nagaland          Jute      Kharif    300.00      300.00
# 3  2004       Jharkhand     Sugarcane  Whole Year    542.97    13958.00
# 4  2026   Uttar Pradesh       Linseed        Rabi  30957.93    18904.19
#
#    Annual_Rainfall  Fertilizer  Pesticide      Yield
# 0            904.1   544902.54     594.49   6.020000
# 1           1073.3   143924.63     324.80   1.100347
# 2           1532.0    30639.00      78.00   0.986667
# 3           1149.2    58825.37     114.02  25.710000
# 4            666.0  5209717.92    8528.93   0.610641

# %%
df.shape
# Out:
# (17400, 10)

# %%
df.shape
# Out:
# (17400, 10)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17400 entries, 0 to 17399
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             17400 non-null  int64
#  1   State            17400 non-null  str
#  2   Crop             17400 non-null  str
#  3   Season           17400 non-null  str
#  4   Area             17400 non-null  float64
#  5   Production       17400 non-null  float64
#  6   Annual_Rainfall  17400 non-null  float64
#  7   Fertilizer       17400 non-null  float64
#  8   Pesticide        17400 non-null  float64
#  9   Yield            17400 non-null  float64
# dtypes: float64(6), int64(1), str(3)
# memory usage: 1.7 MB

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17400 entries, 0 to 17399
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             17400 non-null  int64
#  1   State            17400 non-null  str
#  2   Crop             17400 non-null  str
#  3   Season           17400 non-null  str
#  4   Area             17400 non-null  float64
#  5   Production       17400 non-null  float64
#  6   Annual_Rainfall  17400 non-null  float64
#  7   Fertilizer       17400 non-null  float64
#  8   Pesticide        17400 non-null  float64
#  9   Yield            17400 non-null  float64
# dtypes: float64(6), int64(1), str(3)
# memory usage: 1.7 MB

# %%
df.describe()
# Out:
#                Year          Area    Production  Annual_Rainfall  \
# count  17400.000000  1.740000e+04  1.740000e+04     17400.000000
# mean    2013.585575  1.915141e+05  2.067344e+07      1415.647293
# std        7.875127  6.379056e+05  2.926185e+08       798.514641
# min     2000.000000  5.000000e-01  0.000000e+00       121.000000
# 25%     2007.000000  1.521750e+03  1.595500e+03       925.900000
# 50%     2014.000000  1.110720e+04  1.679159e+04      1217.000000
# 75%     2021.000000  8.953637e+04  1.931845e+05      1632.400000
# max     2026.000000  1.021652e+07  6.647926e+09      6258.800000
#
#          Fertilizer     Pesticide         Yield
# count  1.740000e+04  1.740000e+04  17400.000000
# mean   2.195549e+07  4.234020e+04     96.886642
# std    8.772433e+07  1.712259e+05    978.977056
# min    5.417000e+01  9.000000e-02      0.000000
# 25%    1.274247e+05  3.345525e+02      0.640000
# 50%    8.809784e+05  2.075490e+03      1.098091
# ...

# %%
df.isnull().sum()
# Out:
# Year               0
# State              0
# Crop               0
# Season             0
# Area               0
# Production         0
# Annual_Rainfall    0
# Fertilizer         0
# Pesticide          0
# Yield              0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Year               0
# State              0
# Crop               0
# Season             0
# Area               0
# Production         0
# Annual_Rainfall    0
# Fertilizer         0
# Pesticide          0
# Yield              0
# dtype: int64

# %%
print("Unique States:", df["State"].nunique())
print("Unique Crops:", df["Crop"].nunique())
print("Unique Seasons:", df["Season"].nunique())
# Out:
# Unique States: 31
# Unique Crops: 62
# Unique Seasons: 6

# %%
print("States:")
print(df["State"].unique())

print("\nCrops:")
print(df["Crop"].unique())

print("\nSeasons:")
print(df["Season"].unique())
# Out:
# States:
# <ArrowStringArray>
# [   'Madhya Pradesh',          'Nagaland',         'Jharkhand',
#      'Uttar Pradesh',             'Bihar', 'Jammu and Kashmir',
#       'Chhattisgarh',            'Odisha',             'Assam',
#     'Andhra Pradesh',           'Mizoram',        'Puducherry',
#                'Goa',         'Karnataka',       'Uttarakhand',
#          'Rajasthan',           'Tripura',            'Kerala',
#         'Tamil Nadu',         'Meghalaya',            'Sikkim',
#   'Himachal Pradesh',       'Maharashtra',         'Telangana',
#            'Manipur',           'Gujarat',            'Punjab',
#            'Haryana', 'Arunachal Pradesh',             'Delhi',
#        'West Bengal']
# Length: 31, dtype: str
#
# Crops:
# <ArrowStringArray>
# [         'Sweet potato',             'Sunflower',                  'Jute',
#              'Sugarcane',               'Linseed',                'Lentil',
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Yield"].describe()
# Out:
# count    17400.000000
# mean        96.886642
# std        978.977056
# min          0.000000
# 25%          0.640000
# 50%          1.098091
# 75%          2.830957
# max      21105.000000
# Name: Yield, dtype: float64

# %%
df["Yield"].describe()
# Out:
# count    17400.000000
# mean        96.886642
# std        978.977056
# min          0.000000
# 25%          0.640000
# 50%          1.098091
# 75%          2.830957
# max      21105.000000
# Name: Yield, dtype: float64

# %%
numeric_columns = [
    "Area",
    "Production",
    "Annual_Rainfall",
    "Fertilizer",
    "Pesticide",
    "Yield"
]

(df[numeric_columns] < 0).sum()
# Out:
# Area               0
# Production         0
# Annual_Rainfall    0
# Fertilizer         0
# Pesticide          0
# Yield              0
# dtype: int64

# %%
(df[numeric_columns] == 0).sum()
# Out:
# Area                0
# Production         78
# Annual_Rainfall     0
# Fertilizer          0
# Pesticide           0
# Yield              77
# dtype: int64

# %%
df.dtypes
# Out:
# Year                 int64
# State                  str
# Crop                   str
# Season                 str
# Area               float64
# Production         float64
# Annual_Rainfall    float64
# Fertilizer         float64
# Pesticide          float64
# Yield              float64
# dtype: object

# %%
print(df["State"].unique())
# Out:
# <ArrowStringArray>
# [   'Madhya Pradesh',          'Nagaland',         'Jharkhand',
#      'Uttar Pradesh',             'Bihar', 'Jammu and Kashmir',
#       'Chhattisgarh',            'Odisha',             'Assam',
#     'Andhra Pradesh',           'Mizoram',        'Puducherry',
#                'Goa',         'Karnataka',       'Uttarakhand',
#          'Rajasthan',           'Tripura',            'Kerala',
#         'Tamil Nadu',         'Meghalaya',            'Sikkim',
#   'Himachal Pradesh',       'Maharashtra',         'Telangana',
#            'Manipur',           'Gujarat',            'Punjab',
#            'Haryana', 'Arunachal Pradesh',             'Delhi',
#        'West Bengal']
# Length: 31, dtype: str

# %%
print(df["Crop"].unique())
# Out:
# <ArrowStringArray>
# [         'Sweet potato',             'Sunflower',                  'Jute',
#              'Sugarcane',               'Linseed',                'Lentil',
#                 'Potato',             'Arhar/Tur', 'Peas & beans (Pulses)',
#            'Castor seed',               'Sesamum',                 'Maize',
#               'Turmeric',        'other oilseeds',                 'Mango',
#          'Small millets',          'Dry chillies',     'Moong(Green Gram)',
#          'Other Cereals',                'Barley',                  'Rice',
#     'Other  Rabi pulses',             'Groundnut',                'Garlic',
#                'Tapioca',                  'Gram',                'Ginger',
#                   'Urad',     'Rapeseed &Mustard',                 'Jowar',
#             'Horse-gram',                 'Bajra',             'Safflower',
#                  'Wheat',              'Sannhamp',          'Cotton(lint)',
# ...

# %%
print(df["Season"].unique())
# Out:
# <ArrowStringArray>
# ['Whole Year', 'Kharif', 'Rabi', 'Winter', 'Autumn', 'Summer']
# Length: 6, dtype: str

# %%
df.dropna()
# Out:
#        Year           State          Crop      Season       Area  Production  \
# 0      2009  Madhya Pradesh  Sweet potato  Whole Year    3497.00    20803.00
# 1      2025  Madhya Pradesh     Sunflower      Kharif    1088.98     1198.25
# 2      2001        Nagaland          Jute      Kharif     300.00      300.00
# 3      2004       Jharkhand     Sugarcane  Whole Year     542.97    13958.00
# 4      2026   Uttar Pradesh       Linseed        Rabi   30957.93    18904.19
# ...     ...             ...           ...         ...        ...         ...
# 17395  2019           Assam   Castor seed      Kharif     748.00      345.00
# 17396  2022        Nagaland        Masoor        Rabi    2255.56     1911.66
# 17397  2021       Karnataka         Wheat        Rabi  224443.86   209317.91
# 17398  2019       Karnataka         Mango  Whole Year  223361.81  1645421.71
# 17399  2019  Madhya Pradesh    Niger seed      Kharif    6210.00     2070.00
#
# ...

# %%
df.drop_duplicates()
# Out:
#        Year           State          Crop      Season       Area  Production  \
# 0      2009  Madhya Pradesh  Sweet potato  Whole Year    3497.00    20803.00
# 1      2025  Madhya Pradesh     Sunflower      Kharif    1088.98     1198.25
# 2      2001        Nagaland          Jute      Kharif     300.00      300.00
# 3      2004       Jharkhand     Sugarcane  Whole Year     542.97    13958.00
# 4      2026   Uttar Pradesh       Linseed        Rabi   30957.93    18904.19
# ...     ...             ...           ...         ...        ...         ...
# 17395  2019           Assam   Castor seed      Kharif     748.00      345.00
# 17396  2022        Nagaland        Masoor        Rabi    2255.56     1911.66
# 17397  2021       Karnataka         Wheat        Rabi  224443.86   209317.91
# 17398  2019       Karnataka         Mango  Whole Year  223361.81  1645421.71
# 17399  2019  Madhya Pradesh    Niger seed      Kharif    6210.00     2070.00
#
# ...

# %%
numeric_columns = [
    "Area",
    "Production",
    "Annual_Rainfall",
    "Fertilizer",
    "Pesticide",
    "Yield"
]

(df[numeric_columns] < 0).sum()
# Out:
# Area               0
# Production         0
# Annual_Rainfall    0
# Fertilizer         0
# Pesticide          0
# Yield              0
# dtype: int64

# %%
(numeric_columns == 0).sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 (numeric_columns == 0).sum()
#
# AttributeError: 'bool' object has no attribute 'sum'

# %%
(df[numeric_columns] == 0).sum()
# Out:
# Area                0
# Production         78
# Annual_Rainfall     0
# Fertilizer          0
# Pesticide           0
# Yield              77
# dtype: int64

# %%
(df[numeric_columns] == 0).sum()
# Out:
# Area                0
# Production         78
# Annual_Rainfall     0
# Fertilizer          0
# Pesticide           0
# Yield              77
# dtype: int64

# %%
zero_yield = df[df["Yield"] == 0]

zero_yield.head(10)
# Out:
#       Year           State            Crop      Season      Area  Production  \
# 37    2003  Andhra Pradesh  other oilseeds        Rabi   14609.0         0.0
# 108   2015          Kerala           Onion  Whole Year      27.0         0.0
# 446   2017       Karnataka           Mesta  Whole Year       9.0         0.0
# 542   2004      Tamil Nadu      Niger seed      Kharif    1239.0         0.0
# 720   2005  Andhra Pradesh          Garlic  Whole Year     800.0         0.0
# 933   2002         Haryana          Banana  Whole Year     154.0         0.0
# 960   2009    Chhattisgarh            Jute      Kharif     228.0         0.0
# 1649  2012          Kerala            Urad  Whole Year     265.0         0.0
# 2023  2015    Chhattisgarh            Jute      Kharif     134.0         0.0
# 2141  2017      Tamil Nadu    Cotton(lint)      Kharif  138290.0       337.0
#
#       Annual_Rainfall   Fertilizer  Pesticide  Yield
# 37              826.0   1445998.82    3506.16    0.0
# ...

# %%
zero_yield[[
    "Year",
    "State",
    "Crop",
    "Season",
    "Area",
    "Production",
    "Annual_Rainfall",
    "Fertilizer",
    "Pesticide",
    "Yield"
]]
# Out:
#        Year           State               Crop      Season     Area  \
# 37     2003  Andhra Pradesh     other oilseeds        Rabi  14609.0
# 108    2015          Kerala              Onion  Whole Year     27.0
# 446    2017       Karnataka              Mesta  Whole Year      9.0
# 542    2004      Tamil Nadu         Niger seed      Kharif   1239.0
# 720    2005  Andhra Pradesh             Garlic  Whole Year    800.0
# ...     ...             ...                ...         ...      ...
# 16391  2005     Uttarakhand  Moong(Green Gram)      Kharif      1.0
# 16765  2013  Madhya Pradesh               Jute      Kharif   1054.0
# 17150  2017       Telangana         Horse-gram      Kharif    237.0
# 17166  2013         Haryana           Sannhamp      Kharif     32.0
# 17365  2000         Haryana             Ginger      Kharif     65.0
#
#        Production  Annual_Rainfall  Fertilizer  Pesticide  Yield
# 37            0.0            826.0  1445998.82    3506.16    0.0
# ...

# %%
zero_production = df[df["Production"] == 0]

zero_production[[
    "Year",
    "State",
    "Crop",
    "Season",
    "Area",
    "Production",
    "Yield"
]]
# Out:
#        Year           State               Crop      Season     Area  \
# 37     2003  Andhra Pradesh     other oilseeds        Rabi  14609.0
# 108    2015          Kerala              Onion  Whole Year     27.0
# 446    2017       Karnataka              Mesta  Whole Year      9.0
# 542    2004      Tamil Nadu         Niger seed      Kharif   1239.0
# 720    2005  Andhra Pradesh             Garlic  Whole Year    800.0
# ...     ...             ...                ...         ...      ...
# 16391  2005     Uttarakhand  Moong(Green Gram)      Kharif      1.0
# 16765  2013  Madhya Pradesh               Jute      Kharif   1054.0
# 17150  2017       Telangana         Horse-gram      Kharif    237.0
# 17166  2013         Haryana           Sannhamp      Kharif     32.0
# 17365  2000         Haryana             Ginger      Kharif     65.0
#
#        Production  Yield
# 37            0.0    0.0
# 108           0.0    0.0
# 446           0.0    0.0
# 542           0.0    0.0
# ...

# %%
df = df[df["Production"] > 0].copy()

# %%
# Production = 0 wali rows remove karna
df = df[df["Production"] > 0].copy()

print("New dataset shape:", df.shape)
# Out:
# New dataset shape: (17322, 10)

# %%
print("Production = 0:", (df["Production"] == 0).sum())
print("Yield = 0:", (df["Yield"] == 0).sum())
# Out:
# Production = 0: 0
# Yield = 0: 1

# %%
df = df[df["Production"] > 0].copy()

# %%
print("Production = 0:", (df["Production"] == 0).sum())
print("Yield = 0:", (df["Yield"] == 0).sum())
# Out:
# Production = 0: 0
# Yield = 0: 1

# %%
df[df["Yield"] == 0]
# Out:
#       Year       State          Crop  Season      Area  Production  \
# 2141  2017  Tamil Nadu  Cotton(lint)  Kharif  138290.0       337.0
#
#       Annual_Rainfall  Fertilizer  Pesticide  Yield
# 2141            970.9  21772377.6    52550.2    0.0

# %%
df = df[df["Yield"] > 0].copy()

# %%
df.shape
# Out:
# (17321, 10)

# %%
df.dtypes
# Out:
# Year                 int64
# State                  str
# Crop                   str
# Season                 str
# Area               float64
# Production         float64
# Annual_Rainfall    float64
# Fertilizer         float64
# Pesticide          float64
# Yield              float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Year               0
# State              0
# Crop               0
# Season             0
# Area               0
# Production         0
# Annual_Rainfall    0
# Fertilizer         0
# Pesticide          0
# Yield              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("../dataset/cleaned_crop_yield.csv", index=False)

# %%
print("Missing values:")
print(df.isnull().sum())

print("\nDuplicate rows:")
print(df.duplicated().sum())

print("\nShape:")
print(df.shape)
# Out:
# Missing values:
# Year               0
# State              0
# Crop               0
# Season             0
# Area               0
# Production         0
# Annual_Rainfall    0
# Fertilizer         0
# Pesticide          0
# Yield              0
# dtype: int64
#
# Duplicate rows:
# 0
#
# Shape:
# (17321, 10)

# %%
df.to_csv("../dataset/cleaned_crop_yield.csv", index=False)

# %%
X = df[[
    "Year",
    "State",
    "Crop",
    "Season",
    "Area",
    "Annual_Rainfall",
    "Fertilizer",
    "Pesticide"
]]

y = df["Yield"]

# %%
X.head()
# Out:
#    Year           State          Crop      Season      Area  Annual_Rainfall  \
# 0  2009  Madhya Pradesh  Sweet potato  Whole Year   3497.00            904.1
# 1  2025  Madhya Pradesh     Sunflower      Kharif   1088.98           1073.3
# 2  2001        Nagaland          Jute      Kharif    300.00           1532.0
# 3  2004       Jharkhand     Sugarcane  Whole Year    542.97           1149.2
# 4  2026   Uttar Pradesh       Linseed        Rabi  30957.93            666.0
#
#    Fertilizer  Pesticide
# 0   544902.54     594.49
# 1   143924.63     324.80
# 2    30639.00      78.00
# 3    58825.37     114.02
# 4  5209717.92    8528.93

# %%
y.head()
# Out:
# 0     6.020000
# 1     1.100347
# 2     0.986667
# 3    25.710000
# 4     0.610641
# Name: Yield, dtype: float64

# %%
categorical_features = ["State", "Crop", "Season"]

numerical_features = [
    "Year",
    "Area",
    "Annual_Rainfall",
    "Fertilizer",
    "Pesticide"
]

# %%
categorical_features = ["State", "Crop", "Season"]

numerical_features = [
    "Year",
    "Area",
    "Annual_Rainfall",
    "Fertilizer",
    "Pesticide"
]

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
encoder = OneHotEncoder(handle_unknown="ignore", sparse_output=False)

# %%
X_categorical = encoder.fit_transform(X[categorical_features])

# %%
X_categorical.shape
# Out:
# (17321, 99)

# %%
encoded_columns = encoder.get_feature_names_out(categorical_features)

print(encoded_columns)
# Out:
# ['State_Andhra Pradesh' 'State_Arunachal Pradesh' 'State_Assam'
#  'State_Bihar' 'State_Chhattisgarh' 'State_Delhi' 'State_Goa'
#  'State_Gujarat' 'State_Haryana' 'State_Himachal Pradesh'
#  'State_Jammu and Kashmir' 'State_Jharkhand' 'State_Karnataka'
#  'State_Kerala' 'State_Madhya Pradesh' 'State_Maharashtra' 'State_Manipur'
#  'State_Meghalaya' 'State_Mizoram' 'State_Nagaland' 'State_Odisha'
#  'State_Puducherry' 'State_Punjab' 'State_Rajasthan' 'State_Sikkim'
#  'State_Tamil Nadu' 'State_Telangana' 'State_Tripura'
#  'State_Uttar Pradesh' 'State_Uttarakhand' 'State_West Bengal'
#  'Crop_Arecanut' 'Crop_Arhar/Tur' 'Crop_Bajra' 'Crop_Banana' 'Crop_Barley'
#  'Crop_Black pepper' 'Crop_Cardamom' 'Crop_Cashewnut' 'Crop_Castor seed'
#  'Crop_Coconut' 'Crop_Coriander' 'Crop_Cotton(lint)' 'Crop_Cowpea(Lobia)'
#  'Crop_Dry chillies' 'Crop_Garlic' 'Crop_Ginger' 'Crop_Gram' 'Crop_Grapes'
#  'Crop_Groundnut' 'Crop_Guar seed' 'Crop_Horse-gram' 'Crop_Jowar'
# ...

# %%
X_numerical = X[numerical_features]

# %%
X_numerical.head()
# Out:
#    Year      Area  Annual_Rainfall  Fertilizer  Pesticide
# 0  2009   3497.00            904.1   544902.54     594.49
# 1  2025   1088.98           1073.3   143924.63     324.80
# 2  2001    300.00           1532.0    30639.00      78.00
# 3  2004    542.97           1149.2    58825.37     114.02
# 4  2026  30957.93            666.0  5209717.92    8528.93

# %%
# 6
encoded_columns = encoder.get_feature_names_out(categorical_features)
print(encoded_columns)
# Out:
# ['State_Andhra Pradesh' 'State_Arunachal Pradesh' 'State_Assam'
#  'State_Bihar' 'State_Chhattisgarh' 'State_Delhi' 'State_Goa'
#  'State_Gujarat' 'State_Haryana' 'State_Himachal Pradesh'
#  'State_Jammu and Kashmir' 'State_Jharkhand' 'State_Karnataka'
#  'State_Kerala' 'State_Madhya Pradesh' 'State_Maharashtra' 'State_Manipur'
#  'State_Meghalaya' 'State_Mizoram' 'State_Nagaland' 'State_Odisha'
#  'State_Puducherry' 'State_Punjab' 'State_Rajasthan' 'State_Sikkim'
#  'State_Tamil Nadu' 'State_Telangana' 'State_Tripura'
#  'State_Uttar Pradesh' 'State_Uttarakhand' 'State_West Bengal'
#  'Crop_Arecanut' 'Crop_Arhar/Tur' 'Crop_Bajra' 'Crop_Banana' 'Crop_Barley'
#  'Crop_Black pepper' 'Crop_Cardamom' 'Crop_Cashewnut' 'Crop_Castor seed'
#  'Crop_Coconut' 'Crop_Coriander' 'Crop_Cotton(lint)' 'Crop_Cowpea(Lobia)'
#  'Crop_Dry chillies' 'Crop_Garlic' 'Crop_Ginger' 'Crop_Gram' 'Crop_Grapes'
#  'Crop_Groundnut' 'Crop_Guar seed' 'Crop_Horse-gram' 'Crop_Jowar'
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
print("X_train:", X_train.shape)
print("X_test :", X_test.shape)
print("y_train:", y_train.shape)
print("y_test :", y_test.shape)
# Out:
# X_train: (13856, 8)
# X_test : (3465, 8)
# y_train: (13856,)
# y_test : (3465,)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("categorical", OneHotEncoder(handle_unknown="ignore"), categorical_features)
    ],
    remainder="passthrough"
)

# %%
X_train_encoded = preprocessor.fit_transform(X_train)

# %%
X_test_encoded = preprocessor.transform(X_test)

# %%
transform()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 transform()
#
# NameError: name 'transform' is not defined

# %%
X_train_encoded = preprocessor.fit_transform(X_train)

# %%
X_test_encoded = preprocessor.transform(X_test)

# %%
print("X_train_encoded:", X_train_encoded.shape)
print("X_test_encoded :", X_test_encoded.shape)
# Out:
# X_train_encoded: (13856, 104)
# X_test_encoded : (3465, 104)

# %%
import numpy as np

print("NaN in X_train:", np.isnan(X_train_encoded).sum())
print("NaN in X_test :", np.isnan(X_test_encoded).sum())
print("NaN in y_train:", y_train.isna().sum())
print("NaN in y_test :", y_test.isna().sum())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 3
#       1 import numpy as np
#       2
# ----> 3 print("NaN in X_train:", np.isnan(X_train_encoded).sum())
#       4 print("NaN in X_test :", np.isnan(X_test_encoded).sum())
#       5 print("NaN in y_train:", y_train.isna().sum())
#       6 print("NaN in y_test :", y_test.isna().sum())
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
import numpy as np

print("NaN in X_train:", np.isnan(X_train_encoded).sum())
print("NaN in X_test :", np.isnan(X_test_encoded).sum())
print("NaN in y_train:", y_train.isna().sum())
print("NaN in y_test :", y_test.isna().sum())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 3
#       1 import numpy as np
#       2
# ----> 3 print("NaN in X_train:", np.isnan(X_train_encoded).sum())
#       4 print("NaN in X_test :", np.isnan(X_test_encoded).sum())
#       5 print("NaN in y_train:", y_train.isna().sum())
#       6 print("NaN in y_test :", y_test.isna().sum())
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
print("NaN in X_train:", np.isnan(X_train_encoded).sum())
print("NaN in X_test :", np.isnan(X_test_encoded).sum())
print("NaN in y_train:", y_train.isna().sum())
print("NaN in y_test :", y_test.isna().sum())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 print("NaN in X_train:", np.isnan(X_train_encoded).sum())
#       2 print("NaN in X_test :", np.isnan(X_test_encoded).sum())
#       3 print("NaN in y_train:", y_train.isna().sum())
#       4 print("NaN in y_test :", y_test.isna().sum())
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
print("X_train shape:", X_train_encoded.shape)
print("X_test shape:", X_test_encoded.shape)
# Out:
# X_train shape: (13856, 104)
# X_test shape: (3465, 104)

# %%
print("NaN in y_train:", y_train.isna().sum())
print("NaN in y_test:", y_test.isna().sum())
# Out:
# NaN in y_train: 0
# NaN in y_test: 0

# %%
print("NaN in X_train:", np.asarray(X_train_encoded).astype(float).sum() if False else "checking...")
# Out:
# NaN in X_train: checking...

# %%
from sklearn.linear_model import LinearRegression

# %%
model_lr = LinearRegression()

# %%
model_lr.fit(X_train_encoded, y_train)
# Out:
# LinearRegression()

# %%
y_pred_lr = model_lr.predict(X_test_encoded)

# %%
print(y_pred_lr[:10])
# Out:
# [87.44951926 82.98935785 87.45752782 87.18404672 87.43751869 87.42462169
#  89.48683344 87.42208511 87.49841649 87.43566894]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae_lr = mean_absolute_error(y_test, y_pred_lr)

rmse_lr = mean_squared_error(y_test, y_pred_lr) ** 0.5

r2_lr = r2_score(y_test, y_pred_lr)

print("===== Linear Regression Performance =====")
print("MAE :", mae_lr)
print("RMSE:", rmse_lr)
print("R²  :", r2_lr)
# Out:
# ===== Linear Regression Performance =====
# MAE : 212.59967107947406
# RMSE: 1185.3662676949232
# R²  : -0.001658344657561539

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model_rf = RandomForestRegressor(
    n_estimators=200,
    random_state=42,
    n_jobs=-1
)

# %%
model_rf.fit(X_train_encoded, y_train)
# Out:
# RandomForestRegressor(n_estimators=200, n_jobs=-1, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# 1. Random Forest model
model_rf = RandomForestRegressor(
    n_estimators=200,
    random_state=42,
    n_jobs=-1
)

# 2. Model training
model_rf.fit(X_train_encoded, y_train)

# 3. Prediction
y_pred_rf = model_rf.predict(X_test_encoded)

# 4. Evaluation
mae_rf = mean_absolute_error(y_test, y_pred_rf)
rmse_rf = mean_squared_error(y_test, y_pred_rf) ** 0.5
r2_rf = r2_score(y_test, y_pred_rf)

# 5. Results
print("===== Random Forest Performance =====")
print("MAE :", mae_rf)
print("RMSE:", rmse_rf)
print("R²  :", r2_rf)
# Out:
# ===== Random Forest Performance =====
# MAE : 16.952679246314585
# RMSE: 183.36718757209087
# R²  : 0.9760305685448775

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# 1. XGBoost model
model_xgb = XGBRegressor(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=6,
    random_state=42,
    n_jobs=-1
)

# 2. Training
model_xgb.fit(X_train_encoded, y_train)

# 3. Prediction
y_pred_xgb = model_xgb.predict(X_test_encoded)

# 4. Evaluation
mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
rmse_xgb = mean_squared_error(y_test, y_pred_xgb) ** 0.5
r2_xgb = r2_score(y_test, y_pred_xgb)

# 5. Results
print("===== XGBoost Performance =====")
print("MAE :", mae_xgb)
print("RMSE:", rmse_xgb)
print("R²  :", r2_xgb)
# Out:
# ===== XGBoost Performance =====
# MAE : 18.097022056957986
# RMSE: 193.85829873922677
# R²  : 0.9732093482391996

# %%
feature_names = preprocessor.get_feature_names_out()

importance_df = pd.DataFrame({
    "Feature": feature_names,
    "Importance": model_rf.feature_importances_
})

importance_df = importance_df.sort_values(
    by="Importance",
    ascending=False
)

importance_df.head(20)
# Out:
#                                Feature  Importance
# 40           categorical__Crop_Coconut    0.877479
# 101         remainder__Annual_Rainfall    0.046395
# 103               remainder__Pesticide    0.014467
# 102              remainder__Fertilizer    0.013366
# 100                    remainder__Area    0.012484
# 99                     remainder__Year    0.009797
# 12        categorical__State_Karnataka    0.006725
# 4      categorical__State_Chhattisgarh    0.006049
# 2             categorical__State_Assam    0.004095
# 26        categorical__State_Telangana    0.003670
# 30      categorical__State_West Bengal    0.002159
# 6               categorical__State_Goa    0.001712
# 0    categorical__State_Andhra Pradesh    0.001054
# 25       categorical__State_Tamil Nadu    0.000266
# 83         categorical__Crop_Sugarcane    0.000115
# 21       categorical__State_Puducherry    0.000099
# 34            categorical__Crop_Banana    0.000016
# ...

# %%
df[df["Crop"] == "Coconut"]["Yield"].describe()
# Out:
# count      173.000000
# mean      9218.184980
# std       3521.985925
# min          0.010000
# 25%       6721.946429
# 50%       9197.731201
# 75%      11937.447500
# max      21105.000000
# Name: Yield, dtype: float64

# %%
df = df[df["Yield"] > 0]

# %%
df["Yield"].describe()
# Out:
# count    17321.000000
# mean        97.328489
# std        981.185258
# min          0.003571
# 25%          0.645926
# 50%          1.106667
# 75%          2.857143
# max      21105.000000
# Name: Yield, dtype: float64

# %%
df["Yield"].quantile([0.01, 0.05, 0.25, 0.50, 0.75, 0.95, 0.99])
# Out:
# 0.01      0.069530
# 0.05      0.253182
# 0.25      0.645926
# 0.50      1.106667
# 0.75      2.857143
# 0.95     29.016452
# 0.99    246.582570
# Name: Yield, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.hist(df["Yield"], bins=50)
plt.xlabel("Yield")
plt.ylabel("Frequency")
plt.title("Yield Distribution")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.hist(np.log1p(df["Yield"]), bins=50)
plt.xlabel("log(1 + Yield)")
plt.ylabel("Frequency")
plt.title("Log-Transformed Yield Distribution")
plt.show()

# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Log transform target
y_train_log = np.log1p(y_train)

# Random Forest model
model_rf_log = RandomForestRegressor(
    n_estimators=200,
    random_state=42,
    n_jobs=-1
)

# Train
model_rf_log.fit(X_train_encoded, y_train_log)

# Predict log(Yield)
y_pred_log = model_rf_log.predict(X_test_encoded)

# Convert predictions back to original Yield scale
y_pred_rf_log = np.expm1(y_pred_log)

# Evaluation
mae_rf_log = mean_absolute_error(y_test, y_pred_rf_log)
rmse_rf_log = mean_squared_error(y_test, y_pred_rf_log) ** 0.5
r2_rf_log = r2_score(y_test, y_pred_rf_log)

print("===== Random Forest + Log Target =====")
print("MAE :", mae_rf_log)
print("RMSE:", rmse_rf_log)
print("R²  :", r2_rf_log)
# Out:
# ===== Random Forest + Log Target =====
# MAE : 17.866561722623675
# RMSE: 209.43135622686162
# R²  : 0.9687321589768129

# %%
np.log1p(y_train)
# Out:
# 13299    1.808289
# 7645     2.082769
# 328      2.821466
# 11233    3.799362
# 16564    0.647523
#            ...
# 11330    0.205535
# 12017    0.593327
# 5411     0.699533
# 865      0.644665
# 15866    0.591819
# Name: Yield, Length: 13856, dtype: float64

# %%
np.expm1(...)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'ellipsis' object has no attribute 'expm1'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 np.expm1(...)
#
# TypeError: loop of ufunc does not support argument 0 of type ellipsis which has no callable expm1 method

# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# 1. Log transform target
y_train_log = np.log1p(y_train)

# 2. Model
model_rf_log = RandomForestRegressor(
    n_estimators=200,
    random_state=42,
    n_jobs=-1
)

# 3. Train
model_rf_log.fit(X_train_encoded, y_train_log)

# 4. Prediction
y_pred_log = model_rf_log.predict(X_test_encoded)

# 5. Back to original Yield scale
y_pred_rf_log = np.expm1(y_pred_log)

# 6. Evaluation
mae_rf_log = mean_absolute_error(y_test, y_pred_rf_log)
rmse_rf_log = mean_squared_error(y_test, y_pred_rf_log) ** 0.5
r2_rf_log = r2_score(y_test, y_pred_rf_log)

print("===== Random Forest + Log Target =====")
print("MAE :", mae_rf_log)
print("RMSE:", rmse_rf_log)
print("R²  :", r2_rf_log)
# Out:
# ===== Random Forest + Log Target =====
# MAE : 17.866561722623672
# RMSE: 209.43135622686165
# R²  : 0.9687321589768128

# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# 1. Log transform target
y_train_log = np.log1p(y_train)

# 2. Model
model_rf_log = RandomForestRegressor(
    n_estimators=200,
    random_state=42,
    n_jobs=-1
)

# 3. Train
model_rf_log.fit(X_train_encoded, y_train_log)

# 4. Prediction
y_pred_log = model_rf_log.predict(X_test_encoded)

# 5. Back to original Yield scale
y_pred_rf_log = np.expm1(y_pred_log)

# 6. Evaluation
mae_rf_log = mean_absolute_error(y_test, y_pred_rf_log)
rmse_rf_log = mean_squared_error(y_test, y_pred_rf_log) ** 0.5
r2_rf_log = r2_score(y_test, y_pred_rf_log)

print("===== Random Forest + Log Target =====")
print("MAE :", mae_rf_log)
print("RMSE:", rmse_rf_log)
print("R²  :", r2_rf_log)
# Out:
# ===== Random Forest + Log Target =====
# MAE : 17.866561722623658
# RMSE: 209.43135622686174
# R²  : 0.9687321589768128

# %%
comparison = pd.DataFrame({
    "Actual": y_test.values,
    "Predicted": y_pred_rf
})

comparison.head(20)
# Out:
#        Actual  Predicted
# 0    1.563379   1.694773
# 1    6.884825   7.271758
# 2    1.353688   1.224116
# 3    1.128182   0.874635
# 4    0.010000   0.111686
# 5    0.782000   0.530610
# 6   77.968000  79.374834
# 7    0.106197   0.492739
# 8    1.185385   1.268717
# 9    0.481429   0.504713
# 10   1.663929   1.276069
# 11   2.775000   2.688996
# 12   8.078261   9.665870
# 13   0.813488   0.906443
# 14   0.916474   0.986522
# 15   1.810333   4.145566
# 16  62.628204  67.843577
# 17   1.910769   1.468356
# 18  26.387037  28.014774
# 19   0.631613   0.758908

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

plt.scatter(y_test, y_pred_rf)

plt.xlabel("Actual Yield")
plt.ylabel("Predicted Yield")
plt.title("Actual vs Predicted Yield")

plt.show()

# %%
errors = y_test - y_pred_rf

print("Mean Error:", errors.mean())
print("Maximum Error:", errors.max())
print("Minimum Error:", errors.min())
# Out:
# Mean Error: 2.29068089829148
# Maximum Error: 3699.109344419976
# Minimum Error: -3529.5015112050023

# %%
comparison["Error"] = comparison["Actual"] - comparison["Predicted"]

comparison["Absolute_Error"] = abs(comparison["Error"])

comparison.sort_values(
    "Absolute_Error",
    ascending=False
).head(10)
# Out:
#             Actual     Predicted        Error  Absolute_Error
# 2199  14410.516670  10711.407326  3699.109344     3699.109344
# 1137   9132.568235  12662.069746 -3529.501511     3529.501511
# 529   12467.607500   9374.099765  3093.507735     3093.507735
# 2494  17864.542929  14856.034975  3008.507954     3008.507954
# 2091   6501.101181   9313.058689 -2811.957508     2811.957508
# 3145  16935.058460  14207.947736  2727.110724     2727.110724
# 1195   4164.715926   6758.032694 -2593.316768     2593.316768
# 3061  12664.071223  10364.945005  2299.126218     2299.126218
# 1647   9092.590556   6847.870639  2244.719917     2244.719917
# 2596   4165.395185   6294.347709 -2128.952524     2128.952524

# %%
RandomForestRegressor(
    n_estimators=300,
    max_depth=20,
    min_samples_split=2,
    min_samples_leaf=1,
    random_state=42,
    n_jobs=-1
)
# Out:
# RandomForestRegressor(max_depth=20, n_estimators=300, n_jobs=-1,
#                       random_state=42)

# %%
comparison = pd.DataFrame({
    "Actual_Yield": y_test.values,
    "Predicted_Yield": y_pred_rf
})

comparison.head(20)
# Out:
#     Actual_Yield  Predicted_Yield
# 0       1.563379         1.694773
# 1       6.884825         7.271758
# 2       1.353688         1.224116
# 3       1.128182         0.874635
# 4       0.010000         0.111686
# 5       0.782000         0.530610
# 6      77.968000        79.374834
# 7       0.106197         0.492739
# 8       1.185385         1.268717
# 9       0.481429         0.504713
# 10      1.663929         1.276069
# 11      2.775000         2.688996
# 12      8.078261         9.665870
# 13      0.813488         0.906443
# 14      0.916474         0.986522
# 15      1.810333         4.145566
# 16     62.628204        67.843577
# 17      1.910769         1.468356
# 18     26.387037        28.014774
# 19      0.631613         0.758908

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred_rf)
plt.xlabel("Actual Yield")
plt.ylabel("Predicted Yield")
plt.title("Actual vs Predicted Yield")
plt.show()

# %%
comparison["Error"] = (
    comparison["Actual_Yield"] - comparison["Predicted_Yield"]
)

comparison["Absolute_Error"] = (
    abs(comparison["Error"])
)

comparison.sort_values(
    "Absolute_Error",
    ascending=False
).head(10)
# Out:
#       Actual_Yield  Predicted_Yield        Error  Absolute_Error
# 2199  14410.516670     10711.407326  3699.109344     3699.109344
# 1137   9132.568235     12662.069746 -3529.501511     3529.501511
# 529   12467.607500      9374.099765  3093.507735     3093.507735
# 2494  17864.542929     14856.034975  3008.507954     3008.507954
# 2091   6501.101181      9313.058689 -2811.957508     2811.957508
# 3145  16935.058460     14207.947736  2727.110724     2727.110724
# 1195   4164.715926      6758.032694 -2593.316768     2593.316768
# 3061  12664.071223     10364.945005  2299.126218     2299.126218
# 1647   9092.590556      6847.870639  2244.719917     2244.719917
# 2596   4165.395185      6294.347709 -2128.952524     2128.952524

# %%
print("Mean Error:", comparison["Error"].mean())
print("Mean Absolute Error:", comparison["Absolute_Error"].mean())
# Out:
# Mean Error: 2.29068089829148
# Mean Absolute Error: 16.952679246314585

# %%
plt.figure(figsize=(8, 5))

plt.hist(comparison["Error"], bins=50)

plt.xlabel("Prediction Error")
plt.ylabel("Frequency")
plt.title("Prediction Error Distribution")

plt.show()plt.figure(figsize=(8, 5))

plt.hist(comparison["Error"], bins=50)

plt.xlabel("Prediction Error")
plt.ylabel("Frequency")
plt.title("Prediction Error Distribution")

plt.show()
# Out:
#   Cell In[108], line 9
#     plt.show()plt.figure(figsize=(8, 5))
#               ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(8, 5))

plt.hist(comparison["Error"], bins=50)

plt.xlabel("Prediction Error")
plt.ylabel("Frequency")
plt.title("Prediction Error Distribution")

plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

tuned_rf = RandomForestRegressor(
    n_estimators=300,
    max_depth=20,
    min_samples_split=2,
    min_samples_leaf=1,
    max_features=1.0,
    random_state=42,
    n_jobs=-1
)

# Training
tuned_rf.fit(X_train_encoded, y_train)

# Prediction
y_pred_tuned = tuned_rf.predict(X_test_encoded)

# Evaluation
mae_tuned = mean_absolute_error(y_test, y_pred_tuned)
rmse_tuned = mean_squared_error(y_test, y_pred_tuned) ** 0.5
r2_tuned = r2_score(y_test, y_pred_tuned)

print("===== Tuned Random Forest =====")
print("MAE :", mae_tuned)
print("RMSE:", rmse_tuned)
print("R²  :", r2_tuned)
# Out:
# ===== Tuned Random Forest =====
# MAE : 16.864252709721733
# RMSE: 179.82771437250847
# R²  : 0.9769469849541617

# %%
final_predictions = pd.DataFrame({
    "Actual_Yield": y_test.values,
    "Predicted_Yield": y_pred_tuned
})

final_predictions["Error"] = (
    final_predictions["Actual_Yield"]
    - final_predictions["Predicted_Yield"]
)

final_predictions["Absolute_Error"] = (
    abs(final_predictions["Error"])
)

final_predictions.head(20)
# Out:
#     Actual_Yield  Predicted_Yield     Error  Absolute_Error
# 0       1.563379         1.576563 -0.013184        0.013184
# 1       6.884825         7.311187 -0.426362        0.426362
# 2       1.353688         0.996471  0.357217        0.357217
# 3       1.128182         0.973370  0.154812        0.154812
# 4       0.010000         0.999242 -0.989242        0.989242
# 5       0.782000         0.973370 -0.191370        0.191370
# 6      77.968000        79.544439 -1.576439        1.576439
# 7       0.106197         1.003385 -0.897188        0.897188
# 8       1.185385         1.686074 -0.500689        0.500689
# 9       0.481429         0.973370 -0.491941        0.491941
# 10      1.663929         1.140175  0.523754        0.523754
# 11      2.775000         1.934110  0.840890        0.840890
# 12      8.078261         9.657615 -1.579354        1.579354
# 13      0.813488         1.053197 -0.239709        0.239709
# 14      0.916474         0.996471 -0.079997        0.079997
# ...

# %%
final_predictions.sort_values(
    "Absolute_Error",
    ascending=False
).head(10)
# Out:
#       Actual_Yield  Predicted_Yield        Error  Absolute_Error
# 2199  14410.516670     10639.723290  3770.793380     3770.793380
# 1137   9132.568235     12378.576118 -3246.007883     3246.007883
# 2494  17864.542929     14713.838603  3150.704326     3150.704326
# 529   12467.607500      9367.886514  3099.720986     3099.720986
# 2091   6501.101181      9335.203141 -2834.101960     2834.101960
# 3145  16935.058460     14286.241920  2648.816540     2648.816540
# 1195   4164.715926      6566.255608 -2401.539682     2401.539682
# 1647   9092.590556      6853.480614  2239.109942     2239.109942
# 322    9868.276872      7830.462254  2037.814618     2037.814618
# 3061  12664.071223     10648.053537  2016.017686     2016.017686

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

plt.scatter(
    y_test,
    y_pred_tuned
)

plt.xlabel("Actual Yield")
plt.ylabel("Predicted Yield")
plt.title("Final Model: Actual vs Predicted Yield")

plt.show()

# %%
import joblib

# Final trained model save
joblib.dump(tuned_rf, "../models/crop_yield_model.pkl")

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
import joblib

joblib.dump(tuned_rf, "../models/crop_yield_model.pkl")

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
import joblib

joblib.dump(preprocessor, "../models/preprocessor.pkl")

print("Preprocessor saved successfully!")
# Out:
# Preprocessor saved successfully!

# %%
import joblib

joblib.dump(preprocessor, "../models/preprocessor.pkl")

print("Preprocessor saved successfully!")
# Out:
# Preprocessor saved successfully!

# %%
import joblib

loaded_model = joblib.load("../models/crop_yield_model.pkl")
loaded_preprocessor = joblib.load("../models/preprocessor.pkl")

print("Model loaded successfully!")
print("Preprocessor loaded successfully!")
# Out:
# Model loaded successfully!
# Preprocessor loaded successfully!

# %%
loaded_predictions = loaded_model.predict(X_test_encoded)

print("First 10 predictions:")
print(loaded_predictions[:10])
# Out:
# First 10 predictions:
# [ 1.57656284  7.3111867   0.9964706   0.97337044  0.99924171  0.97337044
#  79.5444395   1.00338487  1.68607383  0.97337044]

# %%
import numpy as np

print(
    "Predictions match:",
    np.allclose(y_pred_tuned[:10], loaded_predictions[:10])
)
# Out:
# Predictions match: True

# %%
def predict_yield(
    year,
    state,
    crop,
    season,
    area,
    annual_rainfall,
    fertilizer,
    pesticide
):
    
    input_data = pd.DataFrame([{
        "Year": year,
        "State": state,
        "Crop": crop,
        "Season": season,
        "Area": area,
        "Annual_Rainfall": annual_rainfall,
        "Fertilizer": fertilizer,
        "Pesticide": pesticide
    }])

    # Preprocess input
    input_encoded = loaded_preprocessor.transform(input_data)

    # Predict
    prediction = loaded_model.predict(input_encoded)

    return prediction[0]

# %%
result = predict_yield(
    year=2025,
    state="Madhya Pradesh",
    crop="Wheat",
    season="Rabi",
    area=1000,
    annual_rainfall=1000,
    fertilizer=50000,
    pesticide=100
)

print("Predicted Yield:", result)
# Out:
# Predicted Yield: 1.5708892045882403

# %%
OneHotEncoder(handle_unknown="ignore")
# Out:
# OneHotEncoder(handle_unknown='ignore')

# %%
year = int(input("Enter Year: "))
state = input("Enter State: ")
crop = input("Enter Crop: ")
season = input("Enter Season: ")
area = float(input("Enter Area: "))
annual_rainfall = float(input("Enter Annual Rainfall: "))
fertilizer = float(input("Enter Fertilizer: "))
pesticide = float(input("Enter Pesticide: "))

result = predict_yield(
    year,
    state,
    crop,
    season,
    area,
    annual_rainfall,
    fertilizer,
    pesticide
)

print("\n🌾 Predicted Crop Yield:", result)
# Out:
# Enter Year:  2025
# Enter State:   Madhya Pradesh
# Enter Crop:  Wheat
# Enter Season:  Rabi
# Enter Area:  1000
# Enter Annual Rainfall:  1000
# Enter Fertilizer:  50000
# Enter Pesticide:  100
# 🌾 Predicted Crop Yield: 1.5708892045882403

# %%
import pandas as pd

model_comparison = pd.DataFrame({
    "Model": [
        "Linear Regression",
        "Random Forest",
        "XGBoost",
        "Tuned Random Forest"
    ],
    "MAE": [
        212.599671,
        16.952679,
        18.097022,
        16.864253
    ],
    "RMSE": [
        1185.366267,
        183.367188,
        193.858299,
        179.827714
    ],
    "R2": [
        -0.001658,
        0.976031,
        0.973209,
        0.976947
    ]
})

model_comparison
# Out:
#                  Model         MAE         RMSE        R2
# 0    Linear Regression  212.599671  1185.366267 -0.001658
# 1        Random Forest   16.952679   183.367188  0.976031
# 2              XGBoost   18.097022   193.858299  0.973209
# 3  Tuned Random Forest   16.864253   179.827714  0.976947

# %%
best_model = model_comparison.loc[
    model_comparison["R2"].idxmax()
]

print("===== BEST MODEL =====")
print("Model :", best_model["Model"])
print("MAE   :", best_model["MAE"])
print("RMSE  :", best_model["RMSE"])
print("R²    :", best_model["R2"])
# Out:
# ===== BEST MODEL =====
# Model : Tuned Random Forest
# MAE   : 16.864253
# RMSE  : 179.827714
# R²    : 0.976947

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))

plt.bar(
    model_comparison["Model"],
    model_comparison["R2"]
)

plt.title("Model Comparison - R² Score")
plt.xlabel("Machine Learning Model")
plt.ylabel("R² Score")

plt.xticks(rotation=20)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))

plt.bar(
    model_comparison["Model"],
    model_comparison["MAE"]
)

plt.title("Model Comparison - MAE")
plt.xlabel("Machine Learning Model")
plt.ylabel("Mean Absolute Error")

plt.xticks(rotation=20)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))

plt.bar(
    model_comparison["Model"],
    model_comparison["RMSE"]
)

plt.title("Model Comparison - RMSE")
plt.xlabel("Machine Learning Model")
plt.ylabel("Root Mean Squared Error")

plt.xticks(rotation=20)

plt.tight_layout()
plt.show()

# %%
print("===== FINAL MODEL =====")
print("Selected Model: Tuned Random Forest")
print("MAE :", round(best_model["MAE"], 2))
print("RMSE:", round(best_model["RMSE"], 2))
print("R²  :", round(best_model["R2"], 5))

print("\nReason:")
print("Tuned Random Forest achieved the highest R² score")
print("and the lowest MAE and RMSE among the tested models.")
# Out:
# ===== FINAL MODEL =====
# Selected Model: Tuned Random Forest
# MAE : 16.86
# RMSE: 179.83
# R²  : 0.97695
#
# Reason:
# Tuned Random Forest achieved the highest R² score
# and the lowest MAE and RMSE among the tested models.
